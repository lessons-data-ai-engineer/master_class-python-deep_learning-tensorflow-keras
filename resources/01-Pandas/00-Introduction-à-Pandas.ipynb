# %% [markdown]
# <a href='http://moncoachdata.com'><img src= 'https://moncoachdata.com/wp-content/uploads/MonCoachData-cours/MonCoachData.jpg' width=400/></a>
#
#
# ---
#
#
# <center><em>Copyright MonCoachData (tous droits réservés)</em></center>
# <center><em>Pour plus d'informations, visitez notre site <a href='http://moncoachdata.com'>moncoachdata.com</a></em></center>
#
#
#
# ---

# %% [markdown]
# # Introduction à Pandas
#
# Dans cette partie du cours, nous apprendrons à utiliser Pandas pour l'analyse de données. Vous pouvez considérer Pandas comme une version extrêmement puissante d'Excel, avec beaucoup plus de fonctionnalités. Dans cette section du cours, vous devez parcourir notebooks dans cet ordre :
#
# * Introduction à Pandas
# * Séries
# * DataFrames
# * Données manquantes
# * GroupBy
# * Opérations
# * Entrée et sortie de données (Data Input et output)
